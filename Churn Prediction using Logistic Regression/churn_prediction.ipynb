# %%
#data set is downloaded from 
#https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('data.csv')

# %%
len(df)
# Out:
# 7043

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
#we can transpose the dataframe using T function so we can see lot more data
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# StreamingTV                     No            No              No
# StreamingMovies                 No            No              No
# Contract            Month-to-month      One year  Month-to-month
# PaperlessBilling               Yes            No             Yes
# PaymentMethod     Electronic check  Mailed check    Mailed check
# MonthlyCharges               29.85         56.95           53.85
# TotalCharges                 29.85        1889.5          108.15
# Churn                           No            No             Yes
#
#                                           3                 4
# customerID                       7795-CFOCW        9237-HQITU
# gender                                 Male            Female
# SeniorCitizen                             0                 0
# Partner                                  No                No
# Dependents                               No                No
# tenure                                   45                 2
# PhoneService                             No               Yes
# MultipleLines              No phone service                No
# InternetService                         DSL       Fiber optic
# OnlineSecurity                          Yes                No
# OnlineBackup                             No                No
# DeviceProtection                        Yes                No
# TechSupport                             Yes                No
# StreamingTV                              No                No
# StreamingMovies                          No                No
# Contract                           One year    Month-to-month
# PaperlessBilling                         No               Yes
# PaymentMethod     Bank transfer (automatic)  Electronic check
# MonthlyCharges                         42.3              70.7
# TotalCharges                        1840.75            151.65
# Churn                                    No               Yes

# %%
#checking if pandas has actually inferred the values correctly or not
#an object means a string value
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#total charges is given an object type but its float value
#the reason is that in some cases, this column contains a space (" ") to represent a missing value
#when pandas comes across nonnumeric characters, it has no option to but give it object type

# %%
#we can force this column to be numeric by converting it to number
#using to_numeric()
total_charges=pd.to_numeric(df.TotalCharges,errors='coerce')


df[total_charges.isnull()][['customerID','TotalCharges']]
# Out:
#       customerID TotalCharges
# 488   4472-LVYGI
# 753   3115-CZMZD
# 936   5709-LVOEQ
# 1082  4367-NUYAO
# 1340  1371-DWPAZ
# 3331  7644-OMVMY
# 3826  3213-VVOLG
# 4380  2520-SGTTA
# 5218  2923-ARZLG
# 6670  4075-WKNIU
# 6754  2775-SEFEE

# %%
#we set the missing values to zero
df.TotalCharges=df.TotalCharges.fillna(0)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
df.columns=df.columns.str.lower().str.replace(' ','_')

string_columns=list(df.dtypes[df.dtypes=='object'].index)

for col in string_columns:
    df[col]=df[col].str.lower().str.replace(' ','_')

# %%
df.churn=(df.churn=='yes').astype(int)

# %%
df.churn.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: churn, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
df_train_full,df_test=train_test_split(df,test_size=0.2,random_state=1)

# %%
df_train_full.head()
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 1814  5442-pptjy    male              0     yes        yes      12
# 5946  6261-rcvns  female              0      no         no      42
# 3881  2176-osjuv    male              0     yes         no      71
# 2389  6161-erdgd    male              0     yes        yes      71
# 3676  2364-ufrom    male              0      no         no      30
#
#      phoneservice multiplelines internetservice       onlinesecurity  ...  \
# 1814          yes            no              no  no_internet_service  ...
# 5946          yes            no             dsl                  yes  ...
# 3881          yes           yes             dsl                  yes  ...
# 2389          yes           yes             dsl                  yes  ...
# 3676          yes            no             dsl                  yes  ...
#
#          deviceprotection          techsupport          streamingtv  \
# 1814  no_internet_service  no_internet_service  no_internet_service
# 5946                  yes                  yes                   no
# 3881                   no                  yes                   no
# 2389                  yes                  yes                  yes
# 3676                   no                  yes                  yes
#
#           streamingmovies  contract paperlessbilling  \
# 1814  no_internet_service  two_year               no
# 5946                  yes  one_year               no
# 3881                   no  two_year               no
# 2389                  yes  one_year               no
# 3676                   no  one_year               no
#
#                   paymentmethod monthlycharges  totalcharges churn
# 1814               mailed_check          19.70        258.35     0
# 5946    credit_card_(automatic)          73.90       3160.55     1
# 3881  bank_transfer_(automatic)          65.15       4681.75     0
# 2389           electronic_check          85.45       6300.85     0
# 3676           electronic_check          70.40       2044.75     0
#
# [5 rows x 21 columns]

# %%
#Because train_test_split splits a dataset into only two parts, we perform 
# the split two times because we need three parts. First, we split the entire dataset into full 
# train and test, and then we split full train into train and validation

# %%
df_train,df_val=train_test_split(df_train_full,test_size=0.33,random_state=11)
#in the above line of code, random_state sets the random seed when doing the split to make sure that everytime
#we run the code, the result is the same

#the next two lines of code, takes the columns with the target variable
y_train=df_train.churn.values
y_val=df_val.churn.values

# Deletes the churn columns from both dataframes to 
# make sure we don’t accidentally use the churn variable 
# as a feature during training
del df_train['churn']
del df_val['churn']

# %%
#Lets check if we need to perform any additional null handling
df_train_full.isnull().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
df_train_full.churn.value_counts()
# Out:
# 0    4113
# 1    1521
# Name: churn, dtype: int64

# %%
global_mean=df_train_full.churn.mean()
round(global_mean,4)
# Out:
# 0.27

# %%
#Lets create two categories of data, numerican and categorical
categorical = ['gender', 'seniorcitizen', 'partner', 'dependents',
 'phoneservice', 'multiplelines', 'internetservice',
 'onlinesecurity', 'onlinebackup', 'deviceprotection',
 'techsupport', 'streamingtv', 'streamingmovies',
 'contract', 'paperlessbilling', 'paymentmethod']
numerical = ['tenure', 'monthlycharges', 'totalcharges']

# %%
#How many unique values each variable has
df_train_full[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %%
#Feature important
#knowing how other variables affect the target variable
#this process of finding out is known as feature importance analysis

female_mean=df_train_full[df_train_full.gender=='female'].churn.mean()
male_mean=df_train_full[df_train_full.gender=='male'].churn.mean()

print('gender==female:',round(female_mean,3))
print('gender==male:',round(male_mean,3))
# Out:
# gender==female: 0.277
# gender==male: 0.263

# %%
partner_yes=df_train_full[df_train_full.partner=='yes'].churn.mean()
partner_no=df_train_full[df_train_full.partner=='no'].churn.mean()

print('partner==yes',round(partner_yes,3))
print('partner==no',round(partner_no,3))
# Out:
# partner==yes 0.205
# partner==no 0.33

# %%
#Calculating the risk of churning
global_mean=df_train_full.churn.mean()
df_group=df_train_full.groupby(by='gender').churn.agg(['mean'])
df_group['diff']=df_group['mean']-global_mean
df_group['risk']=df_group['mean']/global_mean

df_group
# Out:
#             mean      diff      risk
# gender
# female  0.276824  0.006856  1.025396
# male    0.263214 -0.006755  0.974980

# %%
#Mutual information 
#Mutual information is a way to quantify the degree of dependency between two categorical variables
#however it doesn't work when one of the features is numerical
from sklearn.metrics import mutual_info_score

def calculate_mi(series):
    return mutual_info_score(series,df_train_full.churn)

df_mi=df_train_full[categorical].apply(calculate_mi)
df_mi=df_mi.sort_values(ascending=False).to_frame(name='MI')
df_mi
# Out:
#                         MI
# contract          0.098320
# onlinesecurity    0.063085
# techsupport       0.061032
# internetservice   0.055868
# onlinebackup      0.046923
# deviceprotection  0.043453
# paymentmethod     0.043210
# streamingtv       0.031853
# streamingmovies   0.031581
# paperlessbilling  0.017589
# dependents        0.012346
# partner           0.009968
# seniorcitizen     0.009410
# multiplelines     0.000857
# phoneservice      0.000229
# gender            0.000117

# %%
df_train_full[numerical].corrwith(df_train_full.churn)
# Out:
# tenure           -0.351885
# monthlycharges    0.196805
# dtype: float64

# %%
#Feature Engineering 
#One hot encoding
train_dict=df_train[categorical+numerical].to_dict(orient='records')

train_dict
# Out:
# [{'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 71,
#   'monthlycharges': 86.1,
#   'totalcharges': '6045.9'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 60,
#   'monthlycharges': 100.5,
#   'totalcharges': '6029'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 46,
#   'monthlycharges': 45.2,
#   'totalcharges': '2065.15'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 69.15,
#   'totalcharges': '69.15'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 20,
#   'monthlycharges': 98.55,
#   'totalcharges': '1842.8'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 10,
#   'monthlycharges': 19.6,
#   'totalcharges': '189.45'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 51,
#   'monthlycharges': 69.15,
#   'totalcharges': '3649.6'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 14,
#   'monthlycharges': 50.45,
#   'totalcharges': '765.45'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 20,
#   'monthlycharges': 54.0,
#   'totalcharges': '1055.9'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 28,
#   'monthlycharges': 94.5,
#   'totalcharges': '2659.4'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 50,
#   'monthlycharges': 100.65,
#   'totalcharges': '5189.75'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 13,
#   'monthlycharges': 85.95,
#   'totalcharges': '1215.65'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 14,
#   'monthlycharges': 19.75,
#   'totalcharges': '309.35'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 45,
#   'monthlycharges': 98.7,
#   'totalcharges': '4525.8'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 40,
#   'monthlycharges': 103.75,
#   'totalcharges': '4188.4'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 6,
#   'monthlycharges': 49.15,
#   'totalcharges': '270.8'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 66,
#   'monthlycharges': 104.25,
#   'totalcharges': '6860.6'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 56,
#   'monthlycharges': 96.95,
#   'totalcharges': '5432.2'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 2,
#   'monthlycharges': 30.9,
#   'totalcharges': '59.05'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 70,
#   'monthlycharges': 93.9,
#   'totalcharges': '6579.05'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 24,
#   'monthlycharges': 49.7,
#   'totalcharges': '1218.25'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 44,
#   'monthlycharges': 24.85,
#   'totalcharges': '1013.6'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 25,
#   'monthlycharges': 88.95,
#   'totalcharges': '2291.2'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 3,
#   'monthlycharges': 26.4,
#   'totalcharges': '121.25'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 24.75,
#   'totalcharges': '24.75'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 48,
#   'monthlycharges': 106.1,
#   'totalcharges': '5082.8'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 27,
#   'monthlycharges': 49.85,
#   'totalcharges': '1336.15'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 35.45,
#   'totalcharges': '35.45'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 64,
#   'monthlycharges': 20.2,
#   'totalcharges': '1277.75'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 52,
#   'monthlycharges': 105.1,
#   'totalcharges': '5376.4'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 40,
#   'monthlycharges': 25.25,
#   'totalcharges': '1006.9'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 110.1,
#   'totalcharges': '7746.7'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 80.85,
#   'totalcharges': '5727.45'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 3,
#   'monthlycharges': 88.3,
#   'totalcharges': '273.75'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 3,
#   'monthlycharges': 55.8,
#   'totalcharges': '154.55'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 22,
#   'monthlycharges': 101.35,
#   'totalcharges': '2317.1'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 3,
#   'monthlycharges': 73.85,
#   'totalcharges': '196.4'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 27,
#   'monthlycharges': 54.75,
#   'totalcharges': '1510.3'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 43,
#   'monthlycharges': 49.05,
#   'totalcharges': '2076.2'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 9,
#   'monthlycharges': 101.5,
#   'totalcharges': '906.85'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 11,
#   'monthlycharges': 111.4,
#   'totalcharges': '1183.05'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 2,
#   'monthlycharges': 93.85,
#   'totalcharges': '196.75'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 58,
#   'monthlycharges': 100.35,
#   'totalcharges': '5681.1'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 41,
#   'monthlycharges': 74.55,
#   'totalcharges': '3023.55'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 46,
#   'monthlycharges': 100.25,
#   'totalcharges': '4753.85'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 65,
#   'monthlycharges': 105.05,
#   'totalcharges': '6744.25'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 7,
#   'monthlycharges': 99.8,
#   'totalcharges': '673.25'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 69,
#   'monthlycharges': 54.95,
#   'totalcharges': '3772.5'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 29,
#   'monthlycharges': 98.5,
#   'totalcharges': '3004.15'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 28,
#   'monthlycharges': 50.8,
#   'totalcharges': '1386.8'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 4,
#   'monthlycharges': 79.9,
#   'totalcharges': '324.3'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 6,
#   'monthlycharges': 93.55,
#   'totalcharges': '536.4'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 75.3,
#   'totalcharges': '75.3'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 11,
#   'monthlycharges': 84.8,
#   'totalcharges': '906.85'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 45,
#   'monthlycharges': 95.95,
#   'totalcharges': '4456.65'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 44,
#   'monthlycharges': 111.5,
#   'totalcharges': '4915.15'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 21,
#   'monthlycharges': 24.7,
#   'totalcharges': '467.15'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 2,
#   'monthlycharges': 80.2,
#   'totalcharges': '181.1'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 45,
#   'monthlycharges': 102.15,
#   'totalcharges': '4735.35'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 63,
#   'monthlycharges': 104.5,
#   'totalcharges': '6590.8'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 61,
#   'monthlycharges': 75.35,
#   'totalcharges': '4729.3'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 33,
#   'monthlycharges': 44.55,
#   'totalcharges': '1462.6'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 65,
#   'monthlycharges': 103.9,
#   'totalcharges': '6767.1'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 1,
#   'monthlycharges': 75.3,
#   'totalcharges': '75.3'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 38,
#   'monthlycharges': 20.2,
#   'totalcharges': '746.05'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 71,
#   'monthlycharges': 97.65,
#   'totalcharges': '6687.85'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 5,
#   'monthlycharges': 69.95,
#   'totalcharges': '330.15'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 8,
#   'monthlycharges': 76.15,
#   'totalcharges': '645.8'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 22,
#   'monthlycharges': 95.9,
#   'totalcharges': '2234.95'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 72,
#   'monthlycharges': 20.8,
#   'totalcharges': '1521.2'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 17,
#   'monthlycharges': 54.6,
#   'totalcharges': '934.8'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 26,
#   'monthlycharges': 75.0,
#   'totalcharges': '1908.35'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 85.0,
#   'totalcharges': '85'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 85.15,
#   'totalcharges': '6316.2'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 27,
#   'monthlycharges': 50.35,
#   'totalcharges': '1411.35'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 4,
#   'monthlycharges': 77.85,
#   'totalcharges': '299.2'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 57,
#   'monthlycharges': 107.95,
#   'totalcharges': '5969.85'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 31,
#   'monthlycharges': 20.65,
#   'totalcharges': '702.05'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 59,
#   'monthlycharges': 96.65,
#   'totalcharges': '5580.8'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 5,
#   'monthlycharges': 64.0,
#   'totalcharges': '370.25'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 15,
#   'monthlycharges': 50.75,
#   'totalcharges': '688.2'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 49,
#   'monthlycharges': 52.15,
#   'totalcharges': '2583.75'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 32,
#   'monthlycharges': 54.65,
#   'totalcharges': '1830.1'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 58,
#   'monthlycharges': 68.4,
#   'totalcharges': '3972.25'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 45,
#   'monthlycharges': 62.55,
#   'totalcharges': '2796.45'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 47,
#   'monthlycharges': 107.35,
#   'totalcharges': '5118.95'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 46,
#   'monthlycharges': 20.2,
#   'totalcharges': '845.6'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 51,
#   'monthlycharges': 86.35,
#   'totalcharges': '4267.15'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 44,
#   'monthlycharges': 85.15,
#   'totalcharges': '3670.5'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 14,
#   'monthlycharges': 80.45,
#   'totalcharges': '1137.05'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 10,
#   'monthlycharges': 95.25,
#   'totalcharges': '1021.55'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 30,
#   'monthlycharges': 85.0,
#   'totalcharges': '2624.25'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 1,
#   'monthlycharges': 24.8,
#   'totalcharges': '24.8'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 34,
#   'monthlycharges': 75.55,
#   'totalcharges': '2425.4'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 56,
#   'monthlycharges': 65.2,
# ...
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 49.75,
#   'totalcharges': '49.75'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 56,
#   'monthlycharges': 106.8,
#   'totalcharges': '5914.4'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 68,
#   'monthlycharges': 70.95,
#   'totalcharges': '4741.45'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 69.95,
#   'totalcharges': '69.95'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 67,
#   'monthlycharges': 108.75,
#   'totalcharges': '7156.2'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 1,
#   'monthlycharges': 69.75,
#   'totalcharges': '69.75'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 6,
#   'monthlycharges': 55.9,
#   'totalcharges': '365.35'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 6,
#   'monthlycharges': 82.85,
#   'totalcharges': '460.25'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 15,
#   'monthlycharges': 76.5,
#   'totalcharges': '1155.6'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 49,
#   'monthlycharges': 87.2,
#   'totalcharges': '4345'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 27,
#   'monthlycharges': 56.7,
#   'totalcharges': '1652.95'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 50,
#   'monthlycharges': 44.45,
#   'totalcharges': '2188.45'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'electronic_check',
#   'tenure': 22,
#   'monthlycharges': 100.65,
#   'totalcharges': '2415.95'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 12,
#   'monthlycharges': 35.5,
#   'totalcharges': '432.25'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 27,
#   'monthlycharges': 25.85,
#   'totalcharges': '788.55'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 54,
#   'monthlycharges': 55.0,
#   'totalcharges': '3092.65'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 1,
#   'monthlycharges': 69.5,
#   'totalcharges': '69.5'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 24,
#   'monthlycharges': 99.65,
#   'totalcharges': '2404.85'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 41,
#   'monthlycharges': 74.7,
#   'totalcharges': '3187.65'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'no',
#   'multiplelines': 'no_phone_service',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 66,
#   'monthlycharges': 56.6,
#   'totalcharges': '3789.2'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 72,
#   'monthlycharges': 24.75,
#   'totalcharges': '1859.1'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'no',
#   'onlinesecurity': 'no_internet_service',
#   'onlinebackup': 'no_internet_service',
#   'deviceprotection': 'no_internet_service',
#   'techsupport': 'no_internet_service',
#   'streamingtv': 'no_internet_service',
#   'streamingmovies': 'no_internet_service',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 5,
#   'monthlycharges': 20.2,
#   'totalcharges': '83.75'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'no',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 55,
#   'monthlycharges': 103.65,
#   'totalcharges': '5676.65'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'one_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 57,
#   'monthlycharges': 109.4,
#   'totalcharges': '6252.7'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'bank_transfer_(automatic)',
#   'tenure': 7,
#   'monthlycharges': 64.3,
#   'totalcharges': '445.95'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 70,
#   'monthlycharges': 88.55,
#   'totalcharges': '6306.5'},
#  {'gender': 'female',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'electronic_check',
#   'tenure': 16,
#   'monthlycharges': 59.4,
#   'totalcharges': '1023.9'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 1,
#   'monthlycharges': 70.15,
#   'totalcharges': '70.15'},
#  {'gender': 'male',
#   'seniorcitizen': 1,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'credit_card_(automatic)',
#   'tenure': 18,
#   'monthlycharges': 58.4,
#   'totalcharges': '964.9'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'yes',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'no',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'yes',
#   'paymentmethod': 'mailed_check',
#   'tenure': 66,
#   'monthlycharges': 84.0,
#   'totalcharges': '5714.25'},
#  {'gender': 'female',
#   'seniorcitizen': 0,
#   'partner': 'yes',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'yes',
#   'internetservice': 'fiber_optic',
#   'onlinesecurity': 'yes',
#   'onlinebackup': 'yes',
#   'deviceprotection': 'yes',
#   'techsupport': 'yes',
#   'streamingtv': 'yes',
#   'streamingmovies': 'yes',
#   'contract': 'two_year',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 68,
#   'monthlycharges': 118.6,
#   'totalcharges': '7990.05'},
#  {'gender': 'male',
#   'seniorcitizen': 0,
#   'partner': 'no',
#   'dependents': 'no',
#   'phoneservice': 'yes',
#   'multiplelines': 'no',
#   'internetservice': 'dsl',
#   'onlinesecurity': 'no',
#   'onlinebackup': 'no',
#   'deviceprotection': 'no',
#   'techsupport': 'no',
#   'streamingtv': 'no',
#   'streamingmovies': 'no',
#   'contract': 'month-to-month',
#   'paperlessbilling': 'no',
#   'paymentmethod': 'mailed_check',
#   'tenure': 1,
#   'monthlycharges': 45.6,
#   'totalcharges': '45.6'},
#  ...]

# %%
from sklearn.feature_extraction import DictVectorizer
dv=DictVectorizer(sparse=False)
dv.fit(train_dict)
# Out:
# DictVectorizer(sparse=False)

# %%
X_train=dv.transform(train_dict)

# %%
X_train[0]
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %%
dv.get_feature_names_out()
# Out:
# array(['contract=month-to-month', 'contract=one_year',
#        'contract=two_year', ..., 'totalcharges=999.45',
#        'totalcharges=999.9', 'totalcharges=_'], dtype=object)

# %%
from sklearn.linear_model import LogisticRegression 

model=LogisticRegression(solver='liblinear',random_state=1)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=1, solver='liblinear')

# %%
#We can apply it to our validation
# data to obtain the probability of churn for each customer in the validation dataset.

# %%
val_dict=df_val[categorical+numerical].to_dict(orient='records')
X_val=dv.transform(val_dict)

# %%
y_pred=model.predict_proba(X_val)[:,1]

# %%
y_pred
# Out:
# array([0.23796155, 0.29506945, 0.29307723, ..., 0.05503021, 0.65206583,
#        0.08160058])

# %%
churn=y_pred >=0.5

# %%
churn
# Out:
# array([False, False, False, ..., False,  True, False])

# %%
dict(zip(dv.get_feature_names(),model.coef_[0].round(3)))
# Out:
# {'contract=month-to-month': 0.589,
#  'contract=one_year': 0.008,
#  'contract=two_year': -0.734,
#  'dependents=no': -0.019,
#  'dependents=yes': -0.118,
#  'deviceprotection=no': 0.078,
#  'deviceprotection=no_internet_service': -0.182,
#  'deviceprotection=yes': -0.034,
#  'gender=female': -0.033,
#  'gender=male': -0.105,
#  'internetservice=dsl': -0.431,
#  'internetservice=fiber_optic': 0.475,
#  'internetservice=no': -0.182,
#  'monthlycharges': -0.002,
#  'multiplelines=no': -0.191,
#  'multiplelines=no_phone_service': 0.016,
#  'multiplelines=yes': 0.037,
#  'onlinebackup=no': 0.104,
#  'onlinebackup=no_internet_service': -0.182,
#  'onlinebackup=yes': -0.06,
#  'onlinesecurity=no': 0.24,
#  'onlinesecurity=no_internet_service': -0.182,
#  'onlinesecurity=yes': -0.196,
#  'paperlessbilling=no': -0.224,
#  'paperlessbilling=yes': 0.087,
#  'partner=no': -0.054,
#  'partner=yes': -0.083,
#  'paymentmethod=bank_transfer_(automatic)': -0.046,
#  'paymentmethod=credit_card_(automatic)': -0.147,
#  'paymentmethod=electronic_check': 0.192,
#  'paymentmethod=mailed_check': -0.136,
#  'phoneservice=no': 0.016,
#  'phoneservice=yes': -0.154,
#  'seniorcitizen': 0.28,
#  'streamingmovies=no': -0.132,
#  'streamingmovies=no_internet_service': -0.182,
#  'streamingmovies=yes': 0.176,
#  'streamingtv=no': -0.145,
#  'streamingtv=no_internet_service': -0.182,
#  'streamingtv=yes': 0.189,
#  'techsupport=no': 0.17,
#  'techsupport=no_internet_service': -0.182,
#  'techsupport=yes': -0.126,
#  'tenure': -0.034,
#  'totalcharges=100.25': 0.19,
#  'totalcharges=100.4': 0.357,
#  'totalcharges=100.9': -0.106,
#  'totalcharges=1001.5': -0.015,
#  'totalcharges=1004.5': -0.02,
#  'totalcharges=1004.75': -0.179,
#  'totalcharges=1006.9': -0.013,
#  'totalcharges=1007.8': -0.023,
#  'totalcharges=1007.9': -0.016,
#  'totalcharges=1008.55': 0.287,
#  'totalcharges=1008.7': 0.258,
#  'totalcharges=1009.25': -0.243,
#  'totalcharges=101.1': -0.214,
#  'totalcharges=101.9': -0.144,
#  'totalcharges=1011.05': -0.254,
#  'totalcharges=1011.5': -0.222,
#  'totalcharges=1011.8': -0.566,
#  'totalcharges=1012.4': -0.015,
#  'totalcharges=1013.2': -0.011,
#  'totalcharges=1013.6': -0.031,
#  'totalcharges=1016.7': -0.009,
#  'totalcharges=1017.35': -0.54,
#  'totalcharges=102.45': 0.216,
#  'totalcharges=102.75': 0.559,
#  'totalcharges=1020.2': -0.542,
#  'totalcharges=1021.55': -0.558,
#  'totalcharges=1021.75': -0.584,
#  'totalcharges=1022.5': -0.199,
#  'totalcharges=1022.6': -0.012,
#  'totalcharges=1022.95': -0.018,
#  'totalcharges=1023.75': -0.195,
#  'totalcharges=1023.9': 0.497,
#  'totalcharges=1024': -0.05,
#  'totalcharges=1024.65': -0.008,
#  'totalcharges=1025.15': -0.236,
#  'totalcharges=1025.95': 0.392,
#  'totalcharges=1026.35': -0.013,
#  'totalcharges=1028.75': -0.008,
#  'totalcharges=1029.35': -0.395,
#  'totalcharges=1029.8': -0.01,
#  'totalcharges=103.7': -0.262,
#  'totalcharges=1032': 0.501,
#  'totalcharges=1032.05': -0.019,
#  'totalcharges=1036': -0.012,
#  'totalcharges=1036.75': 0.239,
#  'totalcharges=1041.8': -0.013,
#  'totalcharges=1042.65': -0.008,
#  'totalcharges=1043.3': 0.378,
#  'totalcharges=1043.35': 0.482,
#  'totalcharges=1043.8': -0.372,
#  'totalcharges=1045.25': -0.184,
#  'totalcharges=1046.1': 0.172,
#  'totalcharges=1046.2': -0.01,
#  'totalcharges=1046.5': 0.207,
#  'totalcharges=1047.7': 0.237,
#  'totalcharges=1049.05': -0.212,
#  'totalcharges=1051.9': -0.008,
#  'totalcharges=1052.35': 0.931,
#  'totalcharges=1054.75': -0.007,
#  'totalcharges=1055.9': -0.08,
#  'totalcharges=1057.85': -0.007,
#  'totalcharges=1058.1': -0.14,
#  'totalcharges=1058.6': 0.317,
#  'totalcharges=1059.55': 0.222,
#  'totalcharges=106.2': -0.246,
#  'totalcharges=106.8': -0.161,
#  'totalcharges=106.9': -0.033,
#  'totalcharges=1060.2': 0.359,
#  'totalcharges=1061.6': -0.012,
#  'totalcharges=1064.65': 0.244,
#  'totalcharges=1066.15': -0.037,
#  'totalcharges=1066.9': -0.614,
#  'totalcharges=1067.15': 0.704,
#  'totalcharges=1067.65': -0.008,
#  'totalcharges=107.05': -0.118,
#  'totalcharges=107.1': -0.306,
#  'totalcharges=107.6': -0.041,
#  'totalcharges=1070.15': -0.024,
#  'totalcharges=1070.25': -0.008,
#  'totalcharges=1070.5': -0.007,
#  'totalcharges=1070.7': -0.134,
#  'totalcharges=1071.4': -0.193,
#  'totalcharges=1072': 0.293,
#  'totalcharges=1072.6': -0.069,
#  'totalcharges=1073.3': -0.454,
#  'totalcharges=1077.5': 0.645,
#  'totalcharges=1078.9': 0.171,
#  'totalcharges=1079.45': -0.008,
#  'totalcharges=1079.65': -0.006,
#  'totalcharges=108.15': 0.596,
#  'totalcharges=1083.7': -0.271,
#  'totalcharges=1086.75': -0.007,
#  'totalcharges=1087.25': -0.024,
#  'totalcharges=1087.7': -0.009,
#  'totalcharges=1088.25': -0.011,
#  'totalcharges=109.2': -0.122,
#  'totalcharges=109.25': -0.277,
#  'totalcharges=109.5': -0.156,
#  'totalcharges=109.8': -0.118,
#  'totalcharges=1090.65': -0.029,
#  'totalcharges=1093': -0.006,
#  'totalcharges=1093.1': 0.46,
#  'totalcharges=1093.2': -0.235,
#  'totalcharges=1095.3': 0.431,
#  'totalcharges=1095.65': 0.322,
#  'totalcharges=1096.25': 0.228,
#  'totalcharges=1096.65': -0.097,
#  'totalcharges=1098.85': -0.444,
#  'totalcharges=110.15': -0.115,
#  'totalcharges=1101.85': 0.255,
#  'totalcharges=1103.25': -0.008,
#  'totalcharges=1107.2': -0.009,
#  'totalcharges=1107.25': 0.356,
#  'totalcharges=1108': -0.277,
#  'totalcharges=1108.6': -0.428,
#  'totalcharges=111.05': -0.293,
#  'totalcharges=1110.05': -0.007,
#  'totalcharges=1110.35': -0.009,
#  'totalcharges=1110.5': -0.023,
#  'totalcharges=1111.2': -0.221,
#  'totalcharges=1112.3': -0.342,
#  'totalcharges=1114.55': -0.348,
#  'totalcharges=1114.85': -0.041,
#  'totalcharges=1115.15': 0.437,
#  'totalcharges=1119.35': -0.139,
#  'totalcharges=112.3': 0.71,
#  'totalcharges=112.75': -0.122,
#  'totalcharges=1120.3': 0.182,
#  'totalcharges=1120.95': 0.367,
#  'totalcharges=1121.05': -0.013,
#  'totalcharges=1122.4': -0.554,
#  'totalcharges=1123.15': -0.006,
#  'totalcharges=1123.65': -0.008,
#  'totalcharges=1125.6': -0.007,
#  'totalcharges=1126.75': -0.014,
#  'totalcharges=1129.35': -0.464,
#  'totalcharges=1129.75': 0.183,
#  'totalcharges=113.1': -0.314,
#  'totalcharges=113.35': 0.587,
#  'totalcharges=113.85': 0.747,
#  'totalcharges=1130.85': 0.348,
#  'totalcharges=1131.2': 0.152,
#  'totalcharges=1132.35': 0.436,
#  'totalcharges=1132.75': 0.275,
#  'totalcharges=1133.7': -0.027,
#  'totalcharges=1134.25': -0.01,
#  'totalcharges=1135.7': 0.216,
#  'totalcharges=1137.05': -0.257,
#  'totalcharges=1138.8': -0.017,
#  'totalcharges=114.1': 0.466,
#  'totalcharges=1144.5': 0.329,
#  'totalcharges=1144.6': -0.206,
#  'totalcharges=1145.35': 0.194,
#  'totalcharges=1145.7': 0.286,
#  'totalcharges=1146.05': -0.007,
#  'totalcharges=1146.65': 0.297,
#  'totalcharges=1149.65': -0.007,
#  'totalcharges=115.1': 0.512,
#  'totalcharges=1151.05': -0.098,
#  'totalcharges=1151.55': -0.255,
#  'totalcharges=1155.6': -0.215,
#  'totalcharges=1156.35': -0.2,
#  'totalcharges=1157.05': 0.576,
#  'totalcharges=1158.85': -0.008,
#  'totalcharges=116.85': -0.037,
#  'totalcharges=1160.45': -0.01,
#  'totalcharges=1161.75': -0.061,
#  'totalcharges=1164.05': -0.316,
#  'totalcharges=1164.3': 0.221,
#  'totalcharges=1165.6': -0.372,
#  'totalcharges=1165.9': -0.023,
#  'totalcharges=1166.7': -0.247,
#  'totalcharges=1169.35': 0.348,
#  'totalcharges=117.8': -0.074,
#  'totalcharges=1171.3': -0.016,
#  'totalcharges=1171.5': -0.024,
#  'totalcharges=1173.35': -0.01,
#  'totalcharges=1174.35': 0.426,
#  'totalcharges=1174.8': -0.03,
#  'totalcharges=1175.85': -0.168,
#  'totalcharges=1177.05': -0.007,
#  'totalcharges=1177.95': -0.006,
#  'totalcharges=1178.25': 0.385,
#  'totalcharges=1178.4': 0.282,
#  'totalcharges=118.3': 0.42,
#  'totalcharges=118.5': 0.368,
#  'totalcharges=1180.95': 0.289,
#  'totalcharges=1182.55': 0.894,
#  'totalcharges=1183.05': -0.614,
#  'totalcharges=1183.8': -0.255,
#  'totalcharges=1184': -0.42,
#  'totalcharges=1188.25': -0.006,
#  'totalcharges=1189.9': -0.005,
#  'totalcharges=119.75': 0.294,
#  'totalcharges=1191.4': -0.006,
#  'totalcharges=1192.3': -0.009,
#  'totalcharges=1192.7': -0.005,
#  'totalcharges=1193.05': 0.78,
#  'totalcharges=1195.25': -0.011,
#  'totalcharges=1195.95': -0.014,
#  'totalcharges=1199.4': -0.191,
#  'totalcharges=120.25': -0.576,
#  'totalcharges=1200.15': 0.161,
#  'totalcharges=1201.65': -0.155,
#  'totalcharges=1203.9': -0.582,
#  'totalcharges=1203.95': -0.027,
#  'totalcharges=1205.05': -0.005,
#  'totalcharges=1207': -0.468,
#  'totalcharges=1208.15': -0.051,
#  'totalcharges=1208.6': -0.005,
#  'totalcharges=1209.25': -0.005,
#  'totalcharges=121.25': -0.058,
#  'totalcharges=1210.3': -0.007,
#  'totalcharges=1210.4': 0.684,
#  'totalcharges=1215.45': -0.156,
#  'totalcharges=1215.65': -0.608,
#  'totalcharges=1216.35': -0.025,
#  'totalcharges=1218.25': -0.187,
#  'totalcharges=1218.55': 0.171,
#  'totalcharges=1218.65': -0.007,
#  'totalcharges=122': -0.107,
#  'totalcharges=122.9': -0.104,
#  'totalcharges=1221.65': -0.475,
#  'totalcharges=1222.05': 0.401,
#  'totalcharges=1222.25': -0.012,
#  'totalcharges=1222.65': -0.006,
#  'totalcharges=1225.65': -0.005,
#  'totalcharges=123.65': 0.418,
#  'totalcharges=1230.25': 0.364,
#  'totalcharges=1233.4': 0.327,
#  'totalcharges=1234.8': -0.008,
#  'totalcharges=1235.55': -0.367,
#  'totalcharges=1236.15': 0.491,
#  'totalcharges=1237.3': -0.135,
#  'totalcharges=124.4': -0.07,
#  'totalcharges=124.45': -0.038,
#  'totalcharges=1240.15': -0.005,
#  'totalcharges=1242.2': -0.452,
#  'totalcharges=1244.8': -0.011,
#  'totalcharges=1245.05': -0.011,
#  'totalcharges=1248.9': -0.42,
#  'totalcharges=1249.25': -0.194,
#  'totalcharges=125.95': -0.298,
#  'totalcharges=1252.85': -0.007,
#  'totalcharges=1253.5': -0.158,
#  'totalcharges=1253.9': 0.222,
#  'totalcharges=1258.3': 0.309,
#  'totalcharges=1259': 0.315,
#  'totalcharges=1259.35': -0.363,
#  'totalcharges=126.05': 0.751,
#  'totalcharges=1261.7': -0.025,
#  'totalcharges=1263.9': -0.005,
#  'totalcharges=1264.2': -0.277,
#  'totalcharges=1265.65': -0.229,
#  'totalcharges=1266.1': 0.282,
#  'totalcharges=1266.35': -0.086,
#  'totalcharges=1266.4': -0.031,
#  'totalcharges=1267': -0.014,
#  'totalcharges=1267.95': -0.404,
#  'totalcharges=1268.85': -0.006,
#  'totalcharges=127.1': 0.412,
#  'totalcharges=1270.55': -0.008,
#  'totalcharges=1271.8': -0.099,
#  'totalcharges=1274.45': -0.103,
#  'totalcharges=1275.6': -0.013,
#  'totalcharges=1275.7': -0.193,
#  'totalcharges=1277.75': -0.005,
#  'totalcharges=128.6': -0.068,
#  'totalcharges=1281': 0.201,
#  'totalcharges=1282.85': -0.062,
#  'totalcharges=1284.2': 0.184,
#  'totalcharges=1285.05': -0.629,
#  'totalcharges=1288.3': -0.493,
#  'totalcharges=1288.75': -0.209,
#  'totalcharges=129.55': -0.12,
#  'totalcharges=129.6': -0.383,
#  'totalcharges=1291.35': -0.183,
#  'totalcharges=1292.6': -0.005,
#  'totalcharges=1295.4': -0.151,
#  'totalcharges=1296.15': -0.006,
#  'totalcharges=1297.35': -0.005,
#  'totalcharges=1297.8': -0.173,
#  'totalcharges=1298.7': -0.008,
#  'totalcharges=130.5': -0.123,
#  'totalcharges=130.55': -0.144,
#  'totalcharges=1301': 0.292,
#  'totalcharges=1301.1': -0.004,
#  'totalcharges=1301.7': 0.281,
#  'totalcharges=1303.5': -0.005,
#  'totalcharges=1304.8': -0.004,
#  'totalcharges=1304.85': -0.106,
#  'totalcharges=1305.95': -0.005,
#  'totalcharges=1306.3': -0.039,
#  'totalcharges=1308.1': 0.199,
#  'totalcharges=1309': -0.209,
#  'totalcharges=131.05': 0.273,
#  'totalcharges=131.65': 0.2,
#  'totalcharges=1311.6': -0.005,
#  'totalcharges=1311.75': -0.005,
#  'totalcharges=1312.45': -0.142,
#  'totalcharges=1313.55': 0.364,
#  'totalcharges=1316.9': -0.07,
#  'totalcharges=1319.85': -0.115,
#  'totalcharges=132.4': -0.394,
#  'totalcharges=1322.55': -0.387,
#  'totalcharges=1323.7': -0.144,
#  'totalcharges=1326.35': -0.004,
#  'totalcharges=1327.85': -0.097,
#  'totalcharges=1329.2': 0.344,
#  'totalcharges=1331.05': -0.009,
#  'totalcharges=1332.4': -0.411,
#  'totalcharges=1336.1': -0.008,
#  'totalcharges=1336.15': -0.131,
#  'totalcharges=1336.35': -0.014,
#  'totalcharges=1336.9': -0.424,
#  'totalcharges=1337.45': -0.608,
#  'totalcharges=1337.5': -0.005,
#  'totalcharges=1339.8': -0.227,
#  'totalcharges=134.05': -0.674,
#  'totalcharges=134.35': 0.427,
#  'totalcharges=134.5': 0.556,
#  'totalcharges=1340.1': -0.513,
#  'totalcharges=1344.5': -0.006,
#  'totalcharges=1345.55': 0.24,
#  'totalcharges=1345.85': -0.009,
#  'totalcharges=1346.9': -0.112,
#  'totalcharges=1348.95': -0.368,
#  'totalcharges=135.75': -0.716,
#  'totalcharges=1355.45': -0.072,
#  'totalcharges=1356.3': -0.006,
#  'totalcharges=1357.1': -0.004,
#  'totalcharges=1362.85': -0.123,
#  'totalcharges=1364.3': 0.187,
#  'totalcharges=1367.75': -0.163,
#  'totalcharges=137.1': -0.47,
#  'totalcharges=137.25': -0.326,
#  'totalcharges=137.6': 0.535,
#  'totalcharges=137.85': 0.452,
#  'totalcharges=1370.35': -0.244,
#  'totalcharges=1372.45': -0.004,
#  'totalcharges=1372.9': -0.007,
#  'totalcharges=1373.05': -0.355,
#  'totalcharges=1374.2': -0.004,
#  'totalcharges=1374.9': -0.32,
#  'totalcharges=1375.4': -0.005,
#  'totalcharges=1375.6': -0.177,
#  'totalcharges=1378.75': -0.004,
#  'totalcharges=1379.6': -0.004,
#  'totalcharges=138.85': -0.102,
#  'totalcharges=1380.1': 0.743,
#  'totalcharges=1380.4': -0.386,
#  'totalcharges=1381.2': -0.096,
#  'totalcharges=1381.8': -0.34,
#  'totalcharges=1385.85': -0.011,
#  'totalcharges=1386.8': -0.075,
#  'totalcharges=1387': -0.378,
#  'totalcharges=1387.45': -0.005,
#  'totalcharges=1388.45': -0.005,
#  'totalcharges=139.05': 0.2,
#  'totalcharges=139.25': -0.52,
#  'totalcharges=139.4': 0.323,
#  'totalcharges=139.75': -0.102,
#  'totalcharges=1391.15': -0.563,
#  'totalcharges=1391.65': -0.063,
#  'totalcharges=1393.6': -0.205,
#  'totalcharges=1396': -0.008,
#  'totalcharges=1396.9': -0.005,
#  'totalcharges=1397.65': -0.005,
#  'totalcharges=1398.25': -0.219,
#  'totalcharges=140.4': -0.466,
#  'totalcharges=140.7': 0.37,
#  'totalcharges=1400.55': 0.647,
#  'totalcharges=1400.85': 0.365,
#  'totalcharges=1401.15': -0.004,
#  'totalcharges=1402.25': -0.008,
#  'totalcharges=1403.1': -0.011,
#  'totalcharges=1404.65': -0.27,
#  'totalcharges=1406.9': -0.169,
#  'totalcharges=141.1': -0.112,
#  'totalcharges=141.45': 0.246,
#  'totalcharges=1410.25': -0.26,
#  'totalcharges=1411.2': -0.005,
#  'totalcharges=1411.35': -0.11,
#  'totalcharges=1411.9': -0.006,
#  'totalcharges=1412.4': -0.052,
#  'totalcharges=1414.2': -0.04,
#  'totalcharges=1414.65': -0.005,
#  'totalcharges=1415.55': 0.214,
#  'totalcharges=1416.2': -0.201,
#  'totalcharges=1416.5': -0.004,
#  'totalcharges=1416.75': -0.008,
#  'totalcharges=1419.4': -0.006,
#  'totalcharges=142.35': 0.2,
#  'totalcharges=1421.9': -0.004,
#  'totalcharges=1422.1': 0.255,
#  'totalcharges=1423.15': -0.218,
#  'totalcharges=1423.35': -0.05,
#  'totalcharges=1424.2': -0.011,
#  'totalcharges=1424.4': -0.161,
#  'totalcharges=1424.5': 0.454,
#  'totalcharges=1424.6': -0.009,
#  'totalcharges=1424.9': -0.005,
#  'totalcharges=1424.95': 0.264,
#  'totalcharges=1425.45': 0.62,
#  'totalcharges=1426.4': 0.381,
#  'totalcharges=1427.55': -0.119,
#  'totalcharges=143.35': 0.209,
#  'totalcharges=1431.65': -0.021,
#  'totalcharges=1432.55': -0.005,
#  'totalcharges=1434.1': -0.004,
#  'totalcharges=1438.05': -0.321,
#  'totalcharges=144': -0.568,
#  'totalcharges=144.15': 0.194,
#  'totalcharges=144.35': -0.101,
#  'totalcharges=144.55': 0.204,
#  'totalcharges=144.95': -0.118,
#  'totalcharges=1441.65': -0.005,
#  'totalcharges=1441.95': -0.209,
#  'totalcharges=1442.2': -0.485,
#  'totalcharges=1442.6': -0.234,
#  'totalcharges=1443.65': -0.564,
#  'totalcharges=1444.05': -0.013,
#  'totalcharges=1444.65': 0.194,
#  'totalcharges=1445.2': -0.009,
#  'totalcharges=1447.9': -0.007,
#  'totalcharges=1448.8': 0.793,
#  'totalcharges=145.15': -0.247,
#  'totalcharges=1451.1': -0.425,
#  'totalcharges=1451.9': 0.339,
#  'totalcharges=1453.1': -0.149,
#  'totalcharges=1454.25': -0.076,
#  'totalcharges=1457.25': 0.261,
#  'totalcharges=1458.1': -0.004,
#  'totalcharges=1459.35': -0.152,
#  'totalcharges=146.05': 0.194,
#  'totalcharges=146.4': -0.19,
#  'totalcharges=146.6': -0.042,
#  'totalcharges=146.9': 0.365,
#  'totalcharges=1460.85': -0.004,
#  'totalcharges=1461.45': -0.085,
#  'totalcharges=1462.05': -0.008,
#  'totalcharges=1462.6': -0.164,
#  'totalcharges=1463.45': 0.388,
#  'totalcharges=1465.75': 0.285,
#  'totalcharges=1468.75': -0.005,
#  'totalcharges=147.15': 0.554,
#  'totalcharges=147.55': -0.142,
#  'totalcharges=147.75': -0.275,
#  'totalcharges=147.8': -0.372,
#  'totalcharges=1470.05': -0.488,
#  'totalcharges=1470.95': 0.385,
#  'totalcharges=1471.75': 0.286,
#  'totalcharges=1477.65': -0.061,
#  'totalcharges=1478.85': -0.24,
#  'totalcharges=1483.25': 0.305,
#  'totalcharges=1489.3': -0.077,
#  'totalcharges=149.05': -0.432,
#  'totalcharges=149.55': 0.187,
#  'totalcharges=1490.4': -0.371,
#  'totalcharges=1490.95': 0.41,
#  'totalcharges=1492.1': -0.004,
#  'totalcharges=1493.1': -0.011,
#  'totalcharges=1493.2': -0.454,
#  'totalcharges=1493.55': -0.321,
#  'totalcharges=1497.05': -0.186,
#  'totalcharges=1497.9': -0.021,
#  'totalcharges=1498.2': 0.63,
#  'totalcharges=1498.55': -0.146,
#  'totalcharges=1498.65': -0.033,
#  'totalcharges=1498.85': -0.009,
#  'totalcharges=150.35': -0.12,
#  'totalcharges=150.6': -0.118,
#  'totalcharges=150.75': -0.107,
#  'totalcharges=150.85': -0.27,
#  'totalcharges=1500.5': -0.326,
#  'totalcharges=1500.95': -0.004,
#  'totalcharges=1501.75': -0.01,
#  'totalcharges=1502.25': -0.004,
#  'totalcharges=1504.05': 0.215,
#  'totalcharges=1505.05': -0.008,
#  'totalcharges=1505.9': -0.016,
#  'totalcharges=1506.4': -0.014,
#  'totalcharges=1507': -0.1,
#  'totalcharges=151.3': 0.424,
#  'totalcharges=151.75': -0.529,
#  'totalcharges=1510.3': -0.109,
#  'totalcharges=1513.6': -0.011,
#  'totalcharges=1514.85': -0.008,
#  'totalcharges=1515.1': 0.223,
#  'totalcharges=1516.6': -0.075,
#  'totalcharges=1517.5': -0.118,
#  'totalcharges=152.3': -0.275,
#  'totalcharges=152.45': 0.326,
#  'totalcharges=152.6': -0.127,
#  'totalcharges=152.95': -0.18,
#  'totalcharges=1520.1': -0.056,
#  'totalcharges=1520.9': 0.339,
#  'totalcharges=1521.2': -0.006,
#  'totalcharges=1522.7': -0.363,
#  'totalcharges=1524.85': -0.036,
#  'totalcharges=1525.35': -0.076,
#  'totalcharges=1527.35': 0.33,
#  'totalcharges=1529.2': 0.155,
#  'totalcharges=1529.65': -0.004,
#  'totalcharges=153.3': -0.038,
#  'totalcharges=1531.4': 0.182,
#  'totalcharges=1532.45': 0.304,
#  'totalcharges=1533.8': -0.056,
#  'totalcharges=1534.05': -0.007,
#  'totalcharges=1534.75': 0.218,
#  'totalcharges=1536.75': -0.138,
#  'totalcharges=1537.85': -0.054,
#  'totalcharges=1537.9': -0.458,
#  'totalcharges=1539.8': -0.556,
#  'totalcharges=154.55': -0.251,
#  'totalcharges=154.65': 0.633,
#  'totalcharges=154.85': 0.248,
#  'totalcharges=1540.05': -0.498,
#  'totalcharges=1540.2': -0.175,
#  'totalcharges=1540.35': -0.409,
#  'totalcharges=1546.3': -0.052,
#  'totalcharges=155.35': -0.247,
#  'totalcharges=155.8': 0.334,
#  'totalcharges=155.9': -0.118,
#  'totalcharges=1551.6': -0.009,
#  'totalcharges=1553.2': -0.109,
#  'totalcharges=1554.9': -0.008,
#  'totalcharges=1556.85': -0.323,
#  'totalcharges=1559.25': -0.53,
#  'totalcharges=1559.45': -0.116,
#  'totalcharges=156.25': 0.744,
#  'totalcharges=1563.95': -0.01,
#  'totalcharges=1566.75': -0.557,
#  'totalcharges=1567': -0.005,
#  'totalcharges=157.65': -0.112,
#  'totalcharges=1573.95': -0.23,
#  'totalcharges=1574.45': 0.5,
#  'totalcharges=1574.5': -0.006,
#  'totalcharges=158.35': -0.106,
#  'totalcharges=1584.8': -0.007,
#  'totalcharges=1587.55': 0.182,
#  'totalcharges=1588.7': -0.149,
#  'totalcharges=159.15': 0.481,
#  'totalcharges=159.35': -0.034,
#  'totalcharges=159.4': 0.192,
#  'totalcharges=159.45': 0.245,
#  'totalcharges=1595.5': -0.013,
#  'totalcharges=1596.6': -0.177,
#  'totalcharges=160.05': -0.083,
#  'totalcharges=160.75': 0.261,
#  'totalcharges=160.85': -0.252,
#  'totalcharges=1600.25': -0.38,
#  'totalcharges=1600.95': -0.013,
#  'totalcharges=1601.5': -0.433,
#  'totalcharges=1604.5': 0.838,
#  'totalcharges=1607.2': 0.419,
#  'totalcharges=161.45': -0.575,
#  'totalcharges=161.5': 0.197,
#  'totalcharges=161.65': -0.035,
#  'totalcharges=1611.65': -0.17,
#  'totalcharges=1612.75': 0.298,
#  'totalcharges=1614.05': -0.303,
#  'totalcharges=1614.7': -0.685,
#  'totalcharges=1615.1': -0.418,
#  'totalcharges=1618.2': -0.007,
#  'totalcharges=162.15': -0.031,
#  'totalcharges=162.45': 0.219,
#  'totalcharges=1620.2': -0.006,
#  'totalcharges=1620.25': -0.079,
#  'totalcharges=1621.35': -0.115,
#  'totalcharges=1623.4': -0.057,
#  'totalcharges=1629.2': -0.005,
#  'totalcharges=163.7': -0.085,
#  'totalcharges=1630.4': -0.066,
#  'totalcharges=1636.95': -0.079,
#  'totalcharges=1637.3': -0.479,
#  'totalcharges=1638.7': -0.007,
#  'totalcharges=164.5': 0.194,
#  'totalcharges=164.6': -0.111,
#  'totalcharges=164.85': 0.747,
#  'totalcharges=1640': -0.437,
#  'totalcharges=1641.3': -0.448,
#  'totalcharges=1641.8': -0.006,
#  'totalcharges=1642.75': -0.315,
#  'totalcharges=165': 0.398,
#  'totalcharges=165.35': -0.034,
#  'totalcharges=165.45': 0.178,
#  'totalcharges=165.5': -0.029,
#  'totalcharges=1652.4': -0.346,
#  'totalcharges=1652.95': -0.13,
#  'totalcharges=1653.45': -0.236,
#  'totalcharges=1654.75': -0.006,
#  'totalcharges=166.3': 0.209,
#  'totalcharges=1660': 0.288,
#  'totalcharges=1662.05': -0.048,
#  'totalcharges=1663.5': -0.005,
#  'totalcharges=1663.75': -0.178,
#  'totalcharges=1664.3': -0.008,
#  'totalcharges=1665.2': -0.187,
#  'totalcharges=1667.25': -0.261,
#  'totalcharges=1669.4': -0.435,
#  'totalcharges=167.2': -0.411,
#  'totalcharges=167.5': 0.21,
#  'totalcharges=1671.6': -0.574,
#  'totalcharges=1672.1': -0.324,
#  'totalcharges=1672.15': -0.008,
#  'totalcharges=1672.35': -0.255,
#  'totalcharges=1673.4': -0.008,
#  'totalcharges=1673.8': -0.007,
#  'totalcharges=1677.85': -0.264,
#  'totalcharges=1678.05': -0.006,
#  'totalcharges=1679.65': -0.202,
#  'totalcharges=168.15': 0.467,
#  'totalcharges=168.2': 0.157,
#  'totalcharges=168.5': -0.524,
#  'totalcharges=168.65': -0.144,
#  'totalcharges=1680.25': -0.008,
#  'totalcharges=1681.6': -0.007,
#  'totalcharges=1682.05': -0.153,
#  'totalcharges=1682.4': -0.312,
#  'totalcharges=1686.15': -0.005,
#  'totalcharges=1686.85': -0.324,
#  'totalcharges=169.45': 0.441,
#  'totalcharges=1692.6': 0.313,
#  'totalcharges=1696.2': -0.072,
#  'totalcharges=1697.7': -0.006,
#  'totalcharges=170.5': -0.51,
#  'totalcharges=170.9': -0.106,
#  'totalcharges=1700.9': -0.05,
#  'totalcharges=1704.95': 0.54,
#  'totalcharges=1706.45': -0.438,
#  'totalcharges=171': -0.083,
#  'totalcharges=171.15': 0.208,
#  'totalcharges=1710.15': -0.008,
#  'totalcharges=1712.7': 0.295,
#  'totalcharges=1714.95': -0.007,
#  'totalcharges=1716.45': 0.798,
#  'totalcharges=1718.95': -0.191,
#  'totalcharges=1719.15': -0.008,
#  'totalcharges=172.35': -0.061,
#  'totalcharges=172.85': 0.237,
#  'totalcharges=1724.15': -0.006,
#  'totalcharges=1725.95': -0.277,
#  'totalcharges=1727.5': 0.268,
#  'totalcharges=1729.35': -0.353,
#  'totalcharges=173': -0.133,
#  'totalcharges=173.15': -0.072,
#  'totalcharges=1730.65': -0.005,
#  'totalcharges=1732.6': -0.347,
#  'totalcharges=1734.5': -0.044,
#  'totalcharges=1734.65': -0.004,
#  'totalcharges=1738.9': -0.005,
#  'totalcharges=174.2': -0.386,
#  'totalcharges=174.3': 0.239,
#  'totalcharges=174.65': -0.035,
#  'totalcharges=174.7': -0.139,
#  'totalcharges=174.8': 0.133,
#  'totalcharges=1742.45': -0.212,
#  'totalcharges=1742.5': -0.569,
#  'totalcharges=1742.75': 0.522,
#  'totalcharges=1747.2': -0.317,
#  'totalcharges=1748.55': -0.009,
#  'totalcharges=1748.9': -0.048,
#  'totalcharges=1750.85': -0.273,
#  'totalcharges=1752.45': -0.586,
#  'totalcharges=1752.55': 0.171,
#  'totalcharges=1752.65': -0.218,
#  'totalcharges=1753': -0.006,
#  'totalcharges=1755.35': -0.018,
#  'totalcharges=1756.6': -0.217,
#  'totalcharges=1759.4': -0.057,
#  'totalcharges=176.2': -0.319,
#  'totalcharges=1766.75': -0.009,
#  'totalcharges=1767.35': 0.52,
#  'totalcharges=177.4': -0.258,
#  'totalcharges=1775.8': 0.242,
#  'totalcharges=1776': -0.007,
#  'totalcharges=1776.95': 0.284,
#  'totalcharges=1777.6': -0.005,
#  'totalcharges=1777.9': 0.277,
#  'totalcharges=1778.7': -0.007,
#  'totalcharges=1779.95': 0.4,
#  'totalcharges=178.5': 0.766,
#  'totalcharges=178.7': -0.1,
#  'totalcharges=1782': -0.062,
#  'totalcharges=1783.75': -0.29,
#  'totalcharges=1784.5': -0.005,
#  'totalcharges=1784.9': -0.006,
#  'totalcharges=1789.25': 0.361,
#  'totalcharges=179.35': 0.615,
#  'totalcharges=1790.15': -0.005,
#  'totalcharges=1790.35': -0.009,
#  'totalcharges=1790.6': -0.066,
#  'totalcharges=1793.25': -0.339,
#  'totalcharges=1794.8': -0.042,
#  'totalcharges=1796.55': -0.007,
#  'totalcharges=1797.1': -0.005,
#  'totalcharges=1797.75': -0.398,
#  'totalcharges=1798.9': -0.007,
#  'totalcharges=18.8': -0.073,
#  'totalcharges=18.85': 0.677,
#  'totalcharges=18.9': -0.132,
#  'totalcharges=1801.1': -0.088,
#  'totalcharges=1802.15': -0.223,
#  'totalcharges=1803.7': -0.362,
#  'totalcharges=1808.7': 0.268,
#  'totalcharges=181.1': 0.208,
#  'totalcharges=181.5': 0.175,
#  'totalcharges=181.6': 0.444,
#  'totalcharges=181.65': -0.192,
#  'totalcharges=181.7': 0.112,
#  'totalcharges=1810.55': -0.005,
#  'totalcharges=1816.2': -0.009,
#  'totalcharges=1818.3': -0.165,
#  'totalcharges=1821.8': -0.007,
#  'totalcharges=1821.95': -0.508,
#  'totalcharges=1825.5': -0.198,
#  'totalcharges=183.15': -0.078,
#  'totalcharges=183.75': 0.256,
#  'totalcharges=1830.05': -0.006,
#  'totalcharges=1830.1': -0.132,
#  'totalcharges=1832.4': -0.155,
#  'totalcharges=184.15': -0.514,
#  'totalcharges=184.4': -0.065,
#  'totalcharges=1840.75': -0.041,
#  'totalcharges=1842.7': -0.017,
#  'totalcharges=1842.8': 0.196,
#  'totalcharges=1845.9': 0.423,
#  'totalcharges=1849.95': -0.523,
#  'totalcharges=185.2': -0.087,
#  'totalcharges=185.55': 0.214,
#  'totalcharges=185.6': 0.721,
#  'totalcharges=1851.45': -0.004,
#  'totalcharges=1852.85': 0.358,
#  'totalcharges=1855.65': 0.399,
#  'totalcharges=1856.4': -0.012,
#  'totalcharges=1857.25': -0.42,
#  'totalcharges=1857.3': -0.072,
#  'totalcharges=1859.1': -0.004,
#  'totalcharges=1859.2': -0.005,
#  'totalcharges=1859.5': -0.469,
#  'totalcharges=186.15': -0.112,
#  'totalcharges=186.3': -0.37,
#  'totalcharges=1862.9': -0.455,
#  'totalcharges=1863.8': 0.84,
#  'totalcharges=1864.65': -0.064,
#  'totalcharges=1866.45': -0.005,
#  'totalcharges=1867.6': -0.158,
#  'totalcharges=1868.4': -0.454,
#  'totalcharges=187.45': 0.134,
#  'totalcharges=1871.15': -0.366,
#  'totalcharges=1871.85': -0.005,
#  'totalcharges=1874.3': -0.005,
#  'totalcharges=1875.25': -0.018,
#  'totalcharges=188.7': 0.485,
#  'totalcharges=1880.85': 0.74,
#  'totalcharges=1884.65': -0.275,
#  'totalcharges=1885.15': -0.049,
#  'totalcharges=1886.4': -0.086,
#  'totalcharges=1887': -0.006,
#  'totalcharges=1889.5': -0.048,
#  'totalcharges=189.45': -0.065,
#  'totalcharges=189.95': -0.349,
#  'totalcharges=1893.95': 0.318,
#  'totalcharges=19': -0.161,
#  'totalcharges=19.05': -0.132,
#  'totalcharges=19.1': -0.251,
#  'totalcharges=19.15': -0.139,
#  'totalcharges=19.2': -0.276,
#  'totalcharges=19.25': -0.318,
#  'totalcharges=19.3': 0.775,
#  'totalcharges=19.4': -0.288,
#  'totalcharges=19.45': 0.691,
#  'totalcharges=19.5': -0.289,
#  'totalcharges=19.55': -0.356,
#  'totalcharges=19.6': 1.171,
#  'totalcharges=19.65': 1.057,
#  'totalcharges=19.7': -0.119,
#  'totalcharges=19.75': 0.004,
#  'totalcharges=19.85': 0.62,
#  'totalcharges=19.9': 0.978,
#  'totalcharges=19.95': 1.026,
#  'totalcharges=190.05': 0.42,
#  'totalcharges=190.1': -0.367,
#  'totalcharges=190.5': -0.455,
#  'totalcharges=1900.25': 0.572,
#  'totalcharges=1901': -0.007,
#  'totalcharges=1901.05': -0.356,
#  'totalcharges=1901.65': -0.338,
#  'totalcharges=1908.35': -0.096,
#  'totalcharges=191.05': 0.538,
#  'totalcharges=1912.85': -0.12,
#  'totalcharges=1914.9': 0.35,
#  'totalcharges=1916': -0.054,
#  'totalcharges=1923.5': -0.102,
#  'totalcharges=1924.1': -0.032,
#  'totalcharges=1927.3': -0.059,
#  'totalcharges=1929.95': -0.083,
#  'totalcharges=193.05': -0.133,
#  'totalcharges=193.6': 0.591,
#  'totalcharges=1931.3': -0.102,
#  'totalcharges=1934.45': 0.391,
#  'totalcharges=1938.05': -0.331,
#  'totalcharges=1938.9': -0.558,
#  'totalcharges=1939.35': -0.038,
#  'totalcharges=194.55': -0.427,
#  'totalcharges=1940.8': -0.123,
#  'totalcharges=1940.85': -0.006,
#  'totalcharges=1941.5': -0.113,
#  'totalcharges=1943.2': 0.336,
#  'totalcharges=1949.4': -0.419,
#  'totalcharges=195.3': 0.429,
#  'totalcharges=1951': 0.284,
#  'totalcharges=1952.25': -0.234,
#  'totalcharges=1952.8': -0.072,
#  'totalcharges=1955.4': -0.054,
#  'totalcharges=1957.1': -0.22,
#  'totalcharges=1958.45': -0.074,
#  'totalcharges=1958.95': -0.042,
#  'totalcharges=196.4': -0.544,
#  'totalcharges=196.75': -0.023,
#  'totalcharges=196.9': -0.133,
#  'totalcharges=196.95': 0.475,
#  'totalcharges=197.7': 0.18,
#  'totalcharges=1971.15': -0.038,
#  'totalcharges=198.1': -0.099,
#  'totalcharges=198.6': -0.131,
#  'totalcharges=198.7': -0.101,
#  'totalcharges=1982.1': -0.015,
#  'totalcharges=199.75': -0.383,
#  'totalcharges=1990.5': -0.12,
#  'totalcharges=1992.2': -0.237,
#  'totalcharges=1992.95': -0.193,
#  'totalcharges=1993.25': -0.444,
#  'totalcharges=1993.8': 0.317,
#  'totalcharges=1994.3': 0.797,
#  'totalcharges=20.05': 0.511,
#  'totalcharges=20.1': 1.586,
#  'totalcharges=20.15': 1.367,
#  'totalcharges=20.2': 1.089,
#  'totalcharges=20.25': 0.619,
#  'totalcharges=20.3': 0.18,
#  'totalcharges=20.35': -0.381,
#  'totalcharges=20.4': 0.717,
#  'totalcharges=20.45': -0.394,
#  'totalcharges=20.5': 1.631,
#  'totalcharges=20.55': 0.736,
#  'totalcharges=20.6': 0.548,
#  'totalcharges=20.7': -0.177,
#  'totalcharges=20.8': -0.132,
#  'totalcharges=20.9': 0.531,
#  'totalcharges=20.95': -0.141,
#  'totalcharges=2001': -0.411,
#  'totalcharges=2006.1': -0.534,
#  'totalcharges=2006.95': -0.008,
#  'totalcharges=2007.25': -0.398,
#  'totalcharges=2007.85': -0.315,
#  'totalcharges=201': 0.272,
#  'totalcharges=201.1': 0.512,
#  'totalcharges=201.95': -0.24,
#  'totalcharges=2010.55': 0.685,
#  'totalcharges=2011.4': 0.467,
#  'totalcharges=2012.7': 0.362,
#  'totalcharges=2015.35': 0.549,
#  'totalcharges=2015.8': -0.319,
#  'totalcharges=202.15': -0.325,
#  'totalcharges=202.3': -0.269,
#  'totalcharges=202.9': -0.481,
#  'totalcharges=2021.2': -0.04,
#  'totalcharges=2023.55': -0.084,
#  'totalcharges=2024.1': -0.412,
#  'totalcharges=2025.1': -0.624,
#  'totalcharges=2028.8': -0.116,
#  'totalcharges=2029.05': -0.057,
#  'totalcharges=2030.75': -0.125,
#  'totalcharges=2031.95': -0.488,
#  'totalcharges=2032.3': -0.251,
#  'totalcharges=2033.05': -0.199,
#  'totalcharges=2034.25': -0.233,
#  'totalcharges=2038.7': -0.147,
#  'totalcharges=204.55': -0.165,
#  'totalcharges=204.7': 0.205,
#  'totalcharges=2042.05': -0.052,
#  'totalcharges=2043.45': 0.298,
#  'totalcharges=2044.75': -0.07,
#  'totalcharges=2044.95': -0.387,
#  'totalcharges=2045.55': -0.132,
#  'totalcharges=2049.05': -0.103,
#  'totalcharges=2053.05': -0.084,
#  'totalcharges=2058.5': -0.121,
#  'totalcharges=206.15': -0.398,
#  'totalcharges=206.6': 0.508,
#  'totalcharges=2065.15': -0.119,
#  'totalcharges=2065.4': -0.236,
#  'totalcharges=2066': -0.073,
#  'totalcharges=2068.55': 0.568,
#  'totalcharges=2070.75': -0.12,
#  'totalcharges=2072.75': -0.449,
#  'totalcharges=2076.2': 0.542,
#  'totalcharges=208': -0.1,
#  'totalcharges=208.7': 0.458,
#  'totalcharges=2080.1': -0.229,
#  'totalcharges=2085.45': -0.382,
#  'totalcharges=2088.05': -0.47,
#  'totalcharges=2088.8': 0.417,
#  'totalcharges=209.1': 0.331,
#  'totalcharges=2090.25': -0.299,
#  'totalcharges=2093.4': -0.375,
#  'totalcharges=2093.9': -0.084,
#  'totalcharges=2095': 0.303,
#  'totalcharges=2096.1': -0.239,
#  'totalcharges=21.1': -0.132,
#  'totalcharges=210.3': 0.214,
#  'totalcharges=210.65': -0.03,
#  'totalcharges=210.75': 0.366,
#  'totalcharges=2104.55': 0.284,
#  'totalcharges=2106.05': -0.114,
#  'totalcharges=2106.3': -0.102,
#  'totalcharges=2108.35': -0.118,
#  'totalcharges=2109.35': 0.518,
#  'totalcharges=2110.15': 0.375,
#  'totalcharges=2117.2': -0.05,
#  'totalcharges=2119.5': 0.214,
#  'totalcharges=212.3': -0.029,
#  'totalcharges=212.4': -0.616,
#  'totalcharges=2122.05': 0.344,
#  'totalcharges=2122.45': 0.329,
#  'totalcharges=213.35': -0.063,
#  'totalcharges=2134.3': -0.058,
#  'totalcharges=2139.1': -0.159,
#  'totalcharges=214.4': -0.351,
#  'totalcharges=214.55': -0.377,
#  'totalcharges=214.75': -0.362,
#  'totalcharges=2142.8': -0.33,
#  'totalcharges=2145': 0.715,
#  'totalcharges=2146.5': -0.437,
#  'totalcharges=2149.05': -0.438,
#  'totalcharges=215.25': -0.1,
#  'totalcharges=215.8': 0.304,
#  'totalcharges=2156.25': -0.109,
#  'totalcharges=216.2': -0.096,
#  'totalcharges=2162.6': -0.598,
#  'totalcharges=2168.15': -0.232,
#  'totalcharges=2168.9': -0.106,
#  'totalcharges=2169.4': -0.083,
#  'totalcharges=2169.8': 0.395,
#  'totalcharges=217.1': -0.237,
#  'totalcharges=217.45': -0.542,
#  'totalcharges=217.55': 0.446,
#  'totalcharges=2172.05': -0.505,
#  'totalcharges=2180.55': -0.368,
#  'totalcharges=2181.55': -0.099,
#  'totalcharges=2184.6': -0.202,
#  'totalcharges=2184.85': -0.583,
#  'totalcharges=2187.15': -0.421,
#  'totalcharges=2188.45': -0.067,
#  ...}

# %%
customer = {
    'customerid': '8879-zkjof',
    'gender': 'female',
    'seniorcitizen': 0,
    'partner': 'no',
    'dependents': 'no',
    'tenure': 41,
    'phoneservice': 'yes',
    'multiplelines': 'no',
    'internetservice': 'dsl',
    'onlinesecurity': 'yes',
    'onlinebackup': 'no',
    'deviceprotection': 'yes',
    'techsupport': 'yes',
    'streamingtv': 'yes',
    'streamingmovies': 'yes',
    'contract': 'one_year',
    'paperlessbilling': 'yes',
    'paymentmethod': 'bank_transfer_(automatic)',
    'monthlycharges': 79.85,
    'totalcharges': 3320.75,
}

# %%
X_test=dv.transform([customer])

# %%
X_test
# Out:
# array([[0., 1., 0., ..., 0., 0., 0.]])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.91414457, 0.08585543]])

# %%
model.predict_proba(X_test)[0,1]
# Out:
# 0.08585542763264047
